# %%
import book_recommender
print(book_recommender.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import book_recommender
#       2 print(book_recommender.__version__)
#
# ModuleNotFoundError: No module named 'book_recommender'
