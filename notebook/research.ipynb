# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load the data

# %%
book_ratings_df = pd.read_csv("BX-Book-Ratings.csv", sep = ';', on_bad_lines="skip", encoding='latin-1')

# %%
books_df = pd.read_csv("BX-Books.csv", sep = ';', on_bad_lines='skip', encoding='latin-1',low_memory=False)

# %%
users_df = pd.read_csv("BX-Users.csv", sep = ';', on_bad_lines='skip', encoding='latin-1')

# %%
book_ratings_df.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
book_ratings_df.rename(columns={'User-ID':'user_id',
                             'ISBN' : 'isbn',
                             'Book-Rating' : 'rating'}, inplace=True)

# %%
book_ratings_df.head()
# Out:
#    user_id        isbn  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
books_df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
books_df = books_df[['ISBN', 'Book-Title', 'Book-Author','Year-Of-Publication', 'Publisher', 'Image-URL-L']]

# %%
books_df = books_df.rename(columns = {'ISBN':'isbn', 'Book-Title':'title', 
'Book-Author': 'author', 'Year-Of-Publication': 'year_of_publication',
'Publisher':'publisher',
'Image-URL-L':'image_url_L'})

# %%
books_df.head()
# Out:
#          isbn                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author year_of_publication                   publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          image_url_L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
users_df.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users_df.rename(columns=
                {'User-ID' : 'user_id',
                 'Location': 'location',
                 'Age' : 'age'}, inplace=True)

# %%
users_df.head()
# Out:
#    user_id                            location   age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
book_ratings_df.shape
# Out:
# (1149780, 3)

# %%
books_df.shape
# Out:
# (271360, 6)

# %%
users_df.shape
# Out:
# (278858, 3)

# %%
book_ratings_df.isnull().sum()
# Out:
# user_id    0
# isbn       0
# rating     0
# dtype: int64

# %%
books_df.isnull().sum()
# Out:
# isbn                   0
# title                  0
# author                 2
# year_of_publication    0
# publisher              2
# image_url_L            3
# dtype: int64

# %%
books_df[books_df['author'].isna() & books_df['image_url_L'].isna()]
# Out:
# Empty DataFrame
# Columns: [isbn, title, author, year_of_publication, publisher, image_url_L]
# Index: []

# %%
books_df[books_df['author'].isna() & books_df['publisher'].isna()]
# Out:
# Empty DataFrame
# Columns: [isbn, title, author, year_of_publication, publisher, image_url_L]
# Index: []

# %%
books_df.dropna(inplace=True)

# %%
books_df.isnull().sum()
# Out:
# isbn                   0
# title                  0
# author                 0
# year_of_publication    0
# publisher              0
# image_url_L            0
# dtype: int64

# %%
users_df.isnull().sum()
# Out:
# user_id          0
# location         0
# age         110762
# dtype: int64

# %% [markdown]
# # Duplicate values

# %%
book_ratings_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
books_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
users_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Exploratory Dta Analysis

# %%
user_rating_counts = book_ratings_df['user_id'].value_counts()
user_rating_counts
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
active_users = user_rating_counts[user_rating_counts > 200]

# %%
active_users
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 274808      201
# 28634       201
# 59727       201
# 268622      201
# 188951      201
# Name: count, Length: 899, dtype: int64

# %%
active_users.shape
# Out:
# (899,)

# %%
filtered_ratings_df = book_ratings_df[
    book_ratings_df['user_id'].isin(active_users.index)]

# %%
filtered_ratings_df.head()
# Out:
#       user_id        isbn  rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %% [markdown]
# # Merge ratings and books datasets

# %%
ratings_with_books = filtered_ratings_df.merge(books_df, on = 'isbn')

# %%
ratings_with_books.head()
# Out:
#    user_id        isbn  rating  \
# 0   277427  002542730X      10
# 1   277427  0026217457       0
# 2   277427  003008685X       8
# 3   277427  0030615321       0
# 4   277427  0060002050       0
#
#                                                title                 author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...      James Finn Garner
# 1                 Vegetarian Times Complete Cookbook             Lucy  Moll
# 2                                           Pioneers  James Fenimore Cooper
# 3   Ask for May, Settle for June (A Doonesbury book)          G. B. Trudeau
# 4                  On a Wicked Dawn (Cynster Novels)      Stephanie Laurens
#
#   year_of_publication                  publisher  \
# 0                1994  John Wiley &amp; Sons Inc
# 1                1995      John Wiley &amp; Sons
# 2                1974           Thomson Learning
# 3                1982        Henry Holt &amp; Co
# 4                2002                 Avon Books
#
#                                          image_url_L
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/0026217457.0...
# 2  http://images.amazon.com/images/P/003008685X.0...
# 3  http://images.amazon.com/images/P/0030615321.0...
# 4  http://images.amazon.com/images/P/0060002050.0...

# %% [markdown]
# ## Count ratings for each book

# %%
count_ratings = ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
count_ratings
# Out:
#                                                     title  rating
# 0        A Light in the Storm: The Civil War Diary of ...       2
# 1                                   Always Have Popsicles       1
# 2                    Apple Magic (The Collector's series)       1
# 3        Beyond IBM: Leadership Marketing and Finance ...       1
# 4        Clifford Visita El Hospital (Clifford El Gran...       1
# ...                                                   ...     ...
# 160259  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...       3
# 160260                                      Ã?Â?lpiraten.       1
# 160261                     Ã?Â?rger mit Produkt X. Roman.       1
# 160262                              Ã?Â?stlich der Berge.       1
# 160263                                  Ã?Â?thique en toc       1
#
# [160264 rows x 2 columns]

# %%
count_ratings.rename(columns = {'rating' : 'no_of_ratings'}, inplace=True)

# %%
count_ratings
# Out:
#                                                     title  no_of_ratings
# 0        A Light in the Storm: The Civil War Diary of ...              2
# 1                                   Always Have Popsicles              1
# 2                    Apple Magic (The Collector's series)              1
# 3        Beyond IBM: Leadership Marketing and Finance ...              1
# 4        Clifford Visita El Hospital (Clifford El Gran...              1
# ...                                                   ...            ...
# 160259  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...              3
# 160260                                      Ã?Â?lpiraten.              1
# 160261                     Ã?Â?rger mit Produkt X. Roman.              1
# 160262                              Ã?Â?stlich der Berge.              1
# 160263                                  Ã?Â?thique en toc              1
#
# [160264 rows x 2 columns]

# %%
final_ratings_df = ratings_with_books.merge(count_ratings, on='title')

# %%
final_ratings_df.head()
# Out:
#    user_id        isbn  rating  \
# 0   277427  002542730X      10
# 1   277427  0026217457       0
# 2   277427  003008685X       8
# 3   277427  0030615321       0
# 4   277427  0060002050       0
#
#                                                title                 author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...      James Finn Garner
# 1                 Vegetarian Times Complete Cookbook             Lucy  Moll
# 2                                           Pioneers  James Fenimore Cooper
# 3   Ask for May, Settle for June (A Doonesbury book)          G. B. Trudeau
# 4                  On a Wicked Dawn (Cynster Novels)      Stephanie Laurens
#
#   year_of_publication                  publisher  \
# 0                1994  John Wiley &amp; Sons Inc
# 1                1995      John Wiley &amp; Sons
# 2                1974           Thomson Learning
# 3                1982        Henry Holt &amp; Co
# 4                2002                 Avon Books
#
#                                          image_url_L  no_of_ratings
# 0  http://images.amazon.com/images/P/002542730X.0...             82
# 1  http://images.amazon.com/images/P/0026217457.0...              7
# 2  http://images.amazon.com/images/P/003008685X.0...              1
# 3  http://images.amazon.com/images/P/0030615321.0...              1
# 4  http://images.amazon.com/images/P/0060002050.0...             13

# %% [markdown]
# ## books with more than 50 number of ratings

# %%
final_ratings_df = final_ratings_df[final_ratings_df['no_of_ratings'] > 50]

# %%
final_ratings_df.head()
# Out:
#     user_id        isbn  rating  \
# 0    277427  002542730X      10
# 13   277427  0060930535       0
# 15   277427  0060934417       0
# 18   277427  0061009059       9
# 24   277427  006440188X       0
#
#                                                 title  \
# 0   Politically Correct Bedtime Stories: Modern Ta...
# 13                      The Poisonwood Bible: A Novel
# 15                                 Bel Canto: A Novel
# 18  One for the Money (Stephanie Plum Novels (Pape...
# 24                                  The Secret Garden
#
#                      author year_of_publication                  publisher  \
# 0         James Finn Garner                1994  John Wiley &amp; Sons Inc
# 13       Barbara Kingsolver                1999                  Perennial
# 15             Ann Patchett                2002                  Perennial
# 18          Janet Evanovich                1995                HarperTorch
# 24  Frances Hodgson Burnett                1998               HarperTrophy
#
#                                           image_url_L  no_of_ratings
# 0   http://images.amazon.com/images/P/002542730X.0...             82
# 13  http://images.amazon.com/images/P/0060930535.0...            133
# 15  http://images.amazon.com/images/P/0060934417.0...            108
# 18  http://images.amazon.com/images/P/0061009059.0...            108
# 24  http://images.amazon.com/images/P/006440188X.0...             79

# %%
final_ratings_df.isnull().sum()
# Out:
# user_id                0
# isbn                   0
# rating                 0
# title                  0
# author                 0
# year_of_publication    0
# publisher              0
# image_url_L            0
# no_of_ratings          0
# dtype: int64

# %%
final_ratings_df.shape
# Out:
# (59903, 9)

# %%
final_ratings_df.duplicated(subset=['user_id', 'title']).sum()
# Out:
# np.int64(1951)

# %%
dupes = final_ratings_df[final_ratings_df.duplicated(subset=['user_id','title'], keep=False)]
dupes.sort_values(['user_id','title']).head(10)
# Out:
#       user_id        isbn  rating  \
# 5091      254  0439064864       9
# 5092      254  0439064872       9
# 5093      254  0439136350       9
# 5094      254  0439136369       9
# 5070      254  0380789019       0
# 5074      254  0380973634      10
# 5066      254  037582345X       9
# 5187      254  0679879242       8
# 5067      254  0375823468       9
# 5188      254  0679879250       0
#
#                                                   title          author  \
# 5091   Harry Potter and the Chamber of Secrets (Book 2)   J. K. Rowling
# 5092   Harry Potter and the Chamber of Secrets (Book 2)   J. K. Rowling
# 5093  Harry Potter and the Prisoner of Azkaban (Book 3)   J. K. Rowling
# 5094  Harry Potter and the Prisoner of Azkaban (Book 3)   J. K. Rowling
# 5070                                         Neverwhere     Neil Gaiman
# 5074                                         Neverwhere     Neil Gaiman
# 5066    The Golden Compass (His Dark Materials, Book 1)  PHILIP PULLMAN
# 5187    The Golden Compass (His Dark Materials, Book 1)  PHILIP PULLMAN
# 5067      The Subtle Knife (His Dark Materials, Book 2)  PHILIP PULLMAN
# 5188      The Subtle Knife (His Dark Materials, Book 2)  Philip Pullman
#
#      year_of_publication                      publisher  \
# 5091                1999                     Scholastic
# 5092                2000                     Scholastic
# 5093                1999                     Scholastic
# 5094                2001                     Scholastic
# 5070                1998                           Avon
# 5074                1997                 William Morrow
# 5066                2002  Knopf Books for Young Readers
# 5187                1996  Knopf Books for Young Readers
# 5067                2002  Knopf Books for Young Readers
# 5188                1997                Alfred A. Knopf
#
#                                             image_url_L  no_of_ratings
# 5091  http://images.amazon.com/images/P/0439064864.0...            183
# 5092  http://images.amazon.com/images/P/0439064872.0...            183
# 5093  http://images.amazon.com/images/P/0439136350.0...            138
# 5094  http://images.amazon.com/images/P/0439136369.0...            138
# 5070  http://images.amazon.com/images/P/0380789019.0...             72
# 5074  http://images.amazon.com/images/P/0380973634.0...             72
# 5066  http://images.amazon.com/images/P/037582345X.0...            131
# 5187  http://images.amazon.com/images/P/0679879242.0...            131
# 5067  http://images.amazon.com/images/P/0375823468.0...             83
# 5188  http://images.amazon.com/images/P/0679879250.0...             83

# %%
max_ratings = final_ratings_df.groupby(['user_id', 'title'])['rating'].max().reset_index()
max_ratings
# Out:
#        user_id                                              title  rating
# 0          254                                               1984       9
# 1          254                                 A Bend in the Road       0
# 2          254                                     ANGELA'S ASHES       0
# 3          254                                      American Gods      10
# 4          254                    Angela's Ashes (MMP) : A Memoir       0
# ...        ...                                                ...     ...
# 57947   278418                                     Watership Down       0
# 57948   278418                              Welcome to Temptation       0
# 57949   278418  Where the Heart Is (Oprah's Book Club (Paperba...       0
# 57950   278418                           Where the Red Fern Grows       0
# 57951   278418                          Whirlwind (Tyler, Book 1)       0
#
# [57952 rows x 3 columns]

# %%
final_ratings_df.columns
# Out:
# Index(['user_id', 'title', 'rating', 'isbn', 'author', 'year_of_publication',
#        'publisher', 'image_url_L', 'no_of_ratings'],
#       dtype='object')

# %%
final_ratings_df = final_ratings_df.groupby(['user_id', 'title'], as_index=False).agg({
    'rating': 'max',
    'isbn': 'first',
    'author': 'first',
    'year_of_publication': 'first',
    'publisher': 'first',
    'image_url_L': 'first',
    'no_of_ratings': 'first'
})

# %%
final_ratings_df.shape
# Out:
# (57952, 9)

# %% [markdown]
# # Create a pivot table

# %%
book_pivot = final_ratings_df.pivot_table(columns='user_id', index='title', values='rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             2977    3363    3757    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             4017    4385    6242    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     7.0
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             6251    ...  274004  \
# title                                                       ...
# 1984                                                   NaN  ...     NaN
# 1st to Die: A Novel                                    NaN  ...     NaN
# 2nd Chance                                             NaN  ...     NaN
# 4 Blondes                                              0.0  ...     NaN
# 84 Charing Cross Road                                  NaN  ...     NaN
# ...                                                    ...  ...     ...
# Year of Wonders                                        NaN  ...     NaN
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# user_id                                             274061  274301  274308  \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     0.0
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     8.0     NaN
#
# user_id                                             274808  275970  277427  \
# title
# 1984                                                   NaN     0.0     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN    10.0     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     0.0     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user_id                                             277478  277639  278418
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [703 rows x 888 columns]

# %% [markdown]
# The key distinction:
#
# NaN → no data point exists (absence)
#
# 0.0 → a data point exists, and its value happens to be zero (a real recorded "no rating given")

# %%
book_pivot.shape
# Out:
# (703, 888)

# %% [markdown]
# ### Convert the NaNs to 0s before converting to a sparse matrix

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             2977    3363    3757    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             4017    4385    6242    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     7.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             6251    ...  274004  \
# title                                                       ...
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# 84 Charing Cross Road                                  0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# user_id                                             274061  274301  274308  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     8.0     0.0
#
# user_id                                             274808  275970  277427  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0    10.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             277478  277639  278418
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [703 rows x 888 columns]

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 14787 stored elements and shape (703, 888)>

# %% [markdown]
# Only 14,787 user-book rating pairs actually exist out of a possible 703 × 888 = 624,264 combinations.

# %%
sparsity = 1 - (14787 / (703 * 888))
print(f"{sparsity:.2%}")
# Out:
# 97.63%

# %% [markdown]
# That works out to about 97.6% sparse — meaning only ~2.4% of all possible user-book cells have an actual rating.
# The other 97.6% are zeros (either genuinely unrated, or explicit-0 implicit ratings

# %%
type(book_sparse)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors

# %%
book_pivot.index.get_loc("Harry Potter and the Chamber of Secrets (Book 2)")
# Out:
# 224

# %% [markdown]
# ## 1. Test with current Euclidean-based model (already fitted)

# %%
# book_pivot.iloc[237,:]

# %%
model = NearestNeighbors(algorithm='brute', metric='euclidean')
model.fit(book_sparse)

distance, suggestion = model.kneighbors(book_pivot.iloc[224,:].values.reshape(1,-1), n_neighbors=6)

print("Euclidean results:")
for i in suggestion[0]:
    print(book_pivot.index[i])
print("Distances:", distance[0])
# Out:
# Euclidean results:
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Exclusive
# Jacob Have I Loved
# Distances: [ 0.         68.92024376 69.76388751 72.96574539 77.64663547 78.14729682]

# %% [markdown]
# ## 2. Now refit with cosine similarity

# %%
model_cosine = NearestNeighbors(algorithm='brute', metric='cosine')
model_cosine.fit(book_sparse)

distance_cos, suggestion_cos = model_cosine.kneighbors(book_pivot.iloc[224,:].values.reshape(1,-1), n_neighbors=6)

print("\nCosine results:")
for i in suggestion_cos[0]:
    print(book_pivot.index[i])
print("Distances:", distance_cos[0])
# Out:
# Cosine results:
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# Harry Potter and the Order of the Phoenix (Book 5)
# Distances: [1.11022302e-16 3.98252386e-01 4.34412211e-01 5.34821478e-01
#  5.35667246e-01 6.43251541e-01]

# %%
book_pivot.index[224]
# Out:
# 'Harry Potter and the Chamber of Secrets (Book 2)'

# %% [markdown]
# ### Map the neighbor indices to titles (for both models):

# %%
print("Queried book:", book_pivot.index[224])

print("\nEuclidean neighbors:")
for i in suggestion[0]:
    print(book_pivot.index[i])

print("\nCosine neighbors:")
for i in suggestion_cos[0]:
    print(book_pivot.index[i])
# Out:
# Queried book: Harry Potter and the Chamber of Secrets (Book 2)
#
# Euclidean neighbors:
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Exclusive
# Jacob Have I Loved
#
# Cosine neighbors:
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# Harry Potter and the Order of the Phoenix (Book 5)

# %% [markdown]
# ###  To see book + distance together (more useful for comparison):

# %%
print("Euclidean:")
for idx, dist in zip(suggestion[0], distance[0]):
    print(f"{book_pivot.index[idx]}  —  distance: {dist:.4f}")

print("\nCosine:")
for idx, dist in zip(suggestion_cos[0], distance_cos[0]):
    print(f"{book_pivot.index[idx]}  —  distance: {dist:.4f}")
# Out:
# Euclidean:
# Harry Potter and the Chamber of Secrets (Book 2)  —  distance: 0.0000
# Harry Potter and the Prisoner of Azkaban (Book 3)  —  distance: 68.9202
# Harry Potter and the Goblet of Fire (Book 4)  —  distance: 69.7639
# Harry Potter and the Sorcerer's Stone (Book 1)  —  distance: 72.9657
# Exclusive  —  distance: 77.6466
# Jacob Have I Loved  —  distance: 78.1473
#
# Cosine:
# Harry Potter and the Chamber of Secrets (Book 2)  —  distance: 0.0000
# Harry Potter and the Prisoner of Azkaban (Book 3)  —  distance: 0.3983
# Harry Potter and the Goblet of Fire (Book 4)  —  distance: 0.4344
# Harry Potter and the Sorcerer's Stone (Book 1)  —  distance: 0.5348
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))  —  distance: 0.5357
# Harry Potter and the Order of the Phoenix (Book 5)  —  distance: 0.6433

# %%
final_model = NearestNeighbors(algorithm='brute', metric='cosine')
final_model.fit(book_sparse)

distance, suggestion = final_model.kneighbors(book_pivot.iloc[224,:].values.reshape(1,-1), n_neighbors=6)

# %%
distance
# Out:
# array([[1.11022302e-16, 3.98252386e-01, 4.34412211e-01, 5.34821478e-01,
#         5.35667246e-01, 6.43251541e-01]])

# %%
suggestion
# Out:
# array([[224, 227, 225, 228, 229, 226]])

# %%
final_ratings_df[
    final_ratings_df['title'].str.contains('Harry Potter', case=False, na=False)
]
# Out:
#        user_id                                              title  rating  \
# 15         254   Harry Potter and the Chamber of Secrets (Book 2)       9
# 16         254       Harry Potter and the Goblet of Fire (Book 4)       9
# 17         254  Harry Potter and the Order of the Phoenix (Boo...       0
# 18         254  Harry Potter and the Prisoner of Azkaban (Book 3)       9
# 19         254     Harry Potter and the Sorcerer's Stone (Book 1)       9
# ...        ...                                                ...     ...
# 57605   275970   Harry Potter and the Chamber of Secrets (Book 2)       9
# 57606   275970     Harry Potter and the Sorcerer's Stone (Book 1)       9
# 57692   277427   Harry Potter and the Chamber of Secrets (Book 2)       0
# 57693   277427  Harry Potter and the Prisoner of Azkaban (Book 3)       0
# 57694   277427     Harry Potter and the Sorcerer's Stone (Book 1)       0
#
#              isbn         author year_of_publication   publisher  \
# 15     0439064864  J. K. Rowling                1999  Scholastic
# 16     0439139597  J. K. Rowling                2000  Scholastic
# 17     043935806X  J. K. Rowling                2003  Scholastic
# 18     0439136350  J. K. Rowling                1999  Scholastic
# 19     0590353403  J. K. Rowling                1998  Scholastic
# ...           ...            ...                 ...         ...
# 57605  0439420105  J. K. Rowling                2002  Scholastic
# 57606  043936213X  J. K. Rowling                2001  Scholastic
# 57692  0439064872  J. K. Rowling                2000  Scholastic
# 57693  0439136369  J. K. Rowling                2001  Scholastic
# 57694  043936213X  J. K. Rowling                2001  Scholastic
#
#                                              image_url_L  no_of_ratings
# 15     http://images.amazon.com/images/P/0439064864.0...            183
# 16     http://images.amazon.com/images/P/0439139597.0...            125
# 17     http://images.amazon.com/images/P/043935806X.0...            105
# 18     http://images.amazon.com/images/P/0439136350.0...            138
# 19     http://images.amazon.com/images/P/0590353403.0...             78
# ...                                                  ...            ...
# 57605  http://images.amazon.com/images/P/0439420105.0...            183
# 57606  http://images.amazon.com/images/P/043936213X.0...             78
# 57692  http://images.amazon.com/images/P/0439064872.0...            183
# 57693  http://images.amazon.com/images/P/0439136369.0...            138
# 57694  http://images.amazon.com/images/P/043936213X.0...             78
#
# [787 rows x 9 columns]

# %% [markdown]
# # Saving the files

# %%
import pickle
pickle.dump(final_model, open('artifacts/final_model.pkl', 'wb'))
pickle.dump(final_ratings_df,open('artifacts/final_rating.pkl','wb'))
pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))
